# %%
from ollama import chat

response = chat(
    model='codegemma:2b',
    messages=[{'role': 'user', 'content': 'Hello!'}],
)
print(response.message.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 3
#       1 from ollama import chat
#       2
# ----> 3 response = chat(
#       4     model='starcoder2:3b',
#       5     messages=[{'role': 'user', 'content': 'Hello!'}],
#       6 )
#
# File ~/mas-code-sum/.venv/lib/python3.13/site-packages/ollama/_client.py:387, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     340 def chat(
#     341   self,
#     342   model: str = '',
#    (...)    352   keep_alive: Optional[Union[float, str]] = None,
#     353 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     354   """
#     355   Create a chat response using the requested model.
#     356
#    (...)    385   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     386   """
# ...
